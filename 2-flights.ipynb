# %% [markdown]
# # **Instructions**
#
# In this checkpoint, we are going to work on 'The Tunisian flight company: Tunisair' dataset.
#
# Dataset description : This dataset include historical data of flight delays. the objective is to investigate the flight delays factors.
#
# ➡️ Dataset link = https://drive.google.com/file/d/1W7WFOiCZu9qFeKFhM0_1bV7BQWsgSuMv/view

# %%
import pandas as pd 
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# # **Part 1: Data Exploration with Pandas**
#
# 1.	Load the provided dataset into a pandas dataframe
#
# 2.	Use pandas to explore the dataset. For example, you might start by using the head() and info() methods to get an overview of the data.
#
# 3.	Look for missing values in the dataset. You can use the isnull() method to identify missing values.
#
# 4.	Use pandas to calculate some summary statistics for the dataset. For example, you might use the describe() method to get summary statistics for the numerical columns in the dataset.

# %%
# Q1

data=pd.read_csv('second datset-Tunisair_flights_dataset.csv')

data
# Out:
#        Filght_date  Flight_ID Departure point Arrival point  \
# 0       2016-01-03   TU 0712              CMN           TUN
# 1       2016-01-13   TU 0757              MXP           TUN
# 2       2016-01-16   TU 0214              TUN           IST
# 3       2016-01-17   TU 0480              DJE           NTE
# 4       2016-01-17   TU 0338              TUN           ALG
# ...            ...        ...             ...           ...
# 107828  2018-07-05  WKL 0000              TUN           TUN
# 107829  2018-01-13   UG 0003              DJE           TUN
# 107830  2018-11-07  SGT 0000              TUN           TUN
# 107831  2018-01-23   UG 0010              TUN           DJE
# 107832  2018-11-13   UG 0002              TUN           DJE
#
#        Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0           2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1           2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# ...

# %%
data[['Departure point','Arrival point','Arrival delay','Scheduled_departure_time','Scheduled_arrival_time']]
# Out:
#        Departure point Arrival point  Arrival delay Scheduled_departure_time  \
# 0                  CMN           TUN          260.0      2016-01-03 10:30:00
# 1                  MXP           TUN           20.0      2016-01-13 15:05:00
# 2                  TUN           IST            0.0      2016-01-16 04:10:00
# 3                  DJE           NTE            0.0      2016-01-17 14:10:00
# 4                  TUN           ALG           22.0      2016-01-17 14:30:00
# ...                ...           ...            ...                      ...
# 107828             TUN           TUN            0.0      2018-07-05 23:00:00
# 107829             DJE           TUN            0.0      2018-01-13 08:00:00
# 107830             TUN           TUN            0.0      2018-11-07 05:00:00
# 107831             TUN           DJE            0.0      2018-01-23 18:00:00
# 107832             TUN           DJE            0.0      2018-11-13 06:15:00
#
#        Scheduled_arrival_time
# ...

# %%
# Q2

data.head()
# Out:
#   Filght_date Flight_ID Departure point Arrival point  \
# 0  2016-01-03  TU 0712              CMN           TUN
# 1  2016-01-13  TU 0757              MXP           TUN
# 2  2016-01-16  TU 0214              TUN           IST
# 3  2016-01-17  TU 0480              DJE           NTE
# 4  2016-01-17  TU 0338              TUN           ALG
#
#   Scheduled_departure_time Scheduled_arrival_time STATUS Aircraft_code  \
# 0      2016-01-03 10:30:00    2016-01-03 12.55.00    ATA     TU 32AIMN
# 1      2016-01-13 15:05:00    2016-01-13 16.55.00    ATA     TU 31BIMO
# 2      2016-01-16 04:10:00    2016-01-16 06.45.00    ATA     TU 32AIMN
# 3      2016-01-17 14:10:00    2016-01-17 17.00.00    ATA     TU 736IOK
# 4      2016-01-17 14:30:00    2016-01-17 15.50.00    ATA     TU 320IMU
#
#    Arrival delay
# 0          260.0
# 1           20.0
# 2            0.0
# 3            0.0
# 4           22.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107833 entries, 0 to 107832
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Filght_date               107833 non-null  object
#  1   Flight_ID                 107833 non-null  object
#  2   Departure point           107833 non-null  object
#  3   Arrival point             107833 non-null  object
#  4   Scheduled_departure_time  107833 non-null  object
#  5   Scheduled_arrival_time    107833 non-null  object
#  6   STATUS                    107833 non-null  object
#  7   Aircraft_code             107833 non-null  object
#  8   Arrival delay             107833 non-null  float64
# dtypes: float64(1), object(8)
# memory usage: 7.4+ MB

# %%
# Q3

data.isnull().sum()
# Out:
# Filght_date                 0
# Flight_ID                   0
# Departure point             0
# Arrival point               0
# Scheduled_departure_time    0
# Scheduled_arrival_time      0
# STATUS                      0
# Aircraft_code               0
# Arrival delay               0
# dtype: int64

# %%
# Q4 - for numerical columns
 
data.describe()
# Out:
#        Arrival delay
# count  107833.000000
# mean       48.733013
# std       117.135562
# min         0.000000
# 25%         0.000000
# 50%        14.000000
# 75%        43.000000
# max      3451.000000

# %%
# for object columns

data.describe(include='object')
# Out:
#        Filght_date  Flight_ID Departure point Arrival point  \
# count       107833     107833          107833        107833
# unique        1011       1861             132           128
# top     2018-08-31  WKL 0000              TUN           TUN
# freq           183       3105           42522         42572
#
#        Scheduled_departure_time Scheduled_arrival_time  STATUS Aircraft_code
# count                    107833                 107833  107833        107833
# unique                    81697                  85136       5            68
# top         2017-06-23 06:00:00    2018-02-26 09.00.00     ATA     TU 320IMU
# freq                          8                      6   93679          4724

# %% [markdown]
# # **Part 2: Data Exploration with ydata-Profiling**
#
# 1.	Use ydata-profiling to generate a report of the provided dataset.
#
# 2.	Look for missing values in the dataset. You can use the report generated by ydata-profiling to identify missing values.
#
# 3.	Look for correlations between different columns in the dataset. You can use the report generated by ydata-profiling to identify correlations between different columns.
#
# 4.	Identify any outliers or unusual values in the dataset. You can use the report generated by ydata-profiling to identify any outliers or unusual values.

# %%
# Q1

report=ProfileReport(data,title='flight delays_dataset')

report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-22 18:29:49.454333&quot; name=date&gt;&lt;title&gt;flight delays_dataset&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# # **Q2**
#
# in the overview section, we can see clearly that we have no missing values

# %% [markdown]
# # **Q3**
#
# * *Look for correlations between different columns* :
#
# in the report no correlation has been shown as the column types are mostly text, so we can not generate correlation figure or table
#
# in my point of view even if we convert columns (date) type nothing would change, as it is not a parameter that impact the flight in anyway if i am not wrong

# %% [markdown]
# # **Q4**
#
# * Identify any outliers or unusual values in the dataset.
#
# * You can use the report generated by ydata-profiling to identify any outliers or unusual values

# %% [markdown]
# no outliers are visible in the profiling report, as most of variables are text
#
# however the report is concedering "Scheduled_arrival_time" as text instead of datetime as they other datetime variables (flight date + Scheduled_departure_time)

# %% [markdown]
# # **Summary**
#
# At the end of this exercise, write a summary of your findings.
#
# Did you find any interesting patterns or correlations in the data?
#
# Were there any issues or challenges you encountered while exploring the dataset?
#
# Use your summary to reflect on your experience using pandas and ydata-profiling to explore and understand a new dataset.

# %% [markdown]
# #        **answers**
#
# most of the variables are objects, even if we have dates values in columns
#
# but in profiling report, the programme has detected 2 datetime variables
#
# however, there is no missing values in our dataset
#
# as we have objects variables we were not able to vonduct more exploration in terms of finding outliers or checking correlation between variables
